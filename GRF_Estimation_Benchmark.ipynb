# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping

# --- STEP 1: FIXING THE COLUMN NAMES ---
# First, let's see what your columns are actually named
print("Your dataset columns are:", df.columns.tolist())

# EDIT THESE TWO LINES to match what you see in the printout above!
# If your columns are 'Ax', 'Ay', use those. If they are 'sensor1', 'sensor2', use those.
input_cols = [col for col in df.columns if col not in ['Fx', 'Fy', 'Fz', 'target', 'time']]
output_cols = ['Fx', 'Fy', 'Fz']

# Verify the columns exist before scaling
missing_cols = [c for c in input_cols if c not in df.columns]
if missing_cols:
    print(f"Error: These columns were not found: {missing_cols}")
    print("Please check your spelling or capitalization (e.g., 'Accel_X' vs 'accel_x')")
else:
    # --- STEP 2: LOAD AND SCALE DATA ---
    scaler_in = MinMaxScaler(feature_range=(0, 1))
    scaler_out = MinMaxScaler(feature_range=(0, 1))

    scaled_input = scaler_in.fit_transform(df[input_cols].values)
    scaled_output = scaler_out.fit_transform(df[output_cols].values)

    print("Successfully scaled data using columns:", input_cols)

# --- STEP 3: DEFINE THE MODEL ---
model = Sequential([
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    LSTM(128, return_sequences=True), # Increased units for more complex IMU data
    Dropout(0.2),
    LSTM(64),
    Dropout(0.2),
    Dense(len(output_cols))
])

model.compile(optimizer='adam', loss='mse')

# --- STEP 4: TRAIN WITH EARLY STOPPING ---
# Set to 100 epochs. It will stop when it reaches the best accuracy.
early_stop = EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True)

print("Training with IMU + Pressure data...")
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stop],
    verbose=1
)

# --- STEP 5: PREDICT AND REVERT SCALING ---
predictions_scaled = model.predict(X_test)
# Use the OUTPUT scaler to get Newtons back
predictions = scaler_out.inverse_transform(predictions_scaled)
y_actual = scaler_out.inverse_transform(y_test)

# --- STEP 6: CALCULATE ACCURACY (R2) ---
r2_fz = r2_score(y_actual[:, 2], predictions[:, 2])
print(f"\nTarget Axis (Fz) R2 Score: {r2_fz:.4f}")

# --- STEP 7: PLOT THE NEW RESULT ---
plt.figure(figsize=(12, 6))
plt.plot(y_actual[:200, 2], color='black', label='Target (Real Fz)')
plt.plot(predictions[:200, 2], color='blue', linestyle='--', label='LSTM Prediction')
plt.title('IMU + Pressure Fusion: Fz Prediction')
plt.ylabel('Force (N)')
plt.legend()
plt.show()
# Out:
# Your dataset columns are: ['Unnamed: 0', 'timestamp', 'ele_0', 'ele_1', 'ele_2', 'ele_3', 'ele_4', 'ele_5', 'ele_6', 'ele_7', 'ele_8', 'ele_9', 'ele_10', 'ele_11', 'ele_12', 'ele_13', 'ele_14', 'ele_15', 'ele_16', 'ele_17', 'ele_18', 'ele_19', 'ele_20', 'ele_21', 'ele_22', 'ele_23', 'ele_24', 'ele_25', 'ele_26', 'ele_27', 'ele_28', 'ele_29', 'ele_30', 'ele_31', 'ele_32', 'ele_33', 'ele_34', 'ele_35', 'ele_36', 'ele_37', 'Fx', 'Fy', 'Fz', 'Fx_norm', 'Fy_norm', 'Fz_norm']
# Successfully scaled data using columns: ['Unnamed: 0', 'timestamp', 'ele_0', 'ele_1', 'ele_2', 'ele_3', 'ele_4', 'ele_5', 'ele_6', 'ele_7', 'ele_8', 'ele_9', 'ele_10', 'ele_11', 'ele_12', 'ele_13', 'ele_14', 'ele_15', 'ele_16', 'ele_17', 'ele_18', 'ele_19', 'ele_20', 'ele_21', 'ele_22', 'ele_23', 'ele_24', 'ele_25', 'ele_26', 'ele_27', 'ele_28', 'ele_29', 'ele_30', 'ele_31', 'ele_32', 'ele_33', 'ele_34', 'ele_35', 'ele_36', 'ele_37', 'Fx_norm', 'Fy_norm', 'Fz_norm']
# Training with IMU + Pressure data...
# Epoch 1/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0085 - val_loss: 0.0041
# Epoch 2/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 3/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 4/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 5/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 6/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 7/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 8/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 9/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 10/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 11/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 12/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 13/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 14/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 15/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 16/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 17/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 18/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 19/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 20/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 21/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 22/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 23/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 24/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 25/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 26/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 27/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 28/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 29/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 30/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 31/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 32/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 33/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 34/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 35/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 36/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 37/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 38/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 39/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 40/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 41/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 42/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 43/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 44/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 45/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 46/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 47/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 48/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 49/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 50/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 51/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 52/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 53/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 54/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 55/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 56/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 57/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 58/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 59/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 60/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 61/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 62/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 63/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 64/100
# 730/730 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0016 - val_loss: 0.0022
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# Target Axis (Fz) R2 Score: 0.9514

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# STEP 1: RESHAPE DATA
# Deep learning uses 3D data, but Random Forest needs 2D[cite: 1543, 1546].
# We flatten the time steps into a single row.
X_train_rf = X_train.reshape(X_train.shape[0], -1)
X_test_rf = X_test.reshape(X_test.shape[0], -1)

# STEP 2: TRAIN RANDOM FOREST [cite: 1554]
# This is the "simpler" baseline you mentioned in your proposal[cite: 1545, 1547].
rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_model.fit(X_train_rf, y_train)

# STEP 3: PREDICT AND EVALUATE [cite: 1557]
rf_preds_scaled = rf_model.predict(X_test_rf)
rf_preds = scaler_out.inverse_transform(rf_preds_scaled)
y_true = scaler_out.inverse_transform(y_test)

# Calculate NRMSE for your report [cite: 29, 1557]
mse_rf = mean_squared_error(y_true, rf_preds)
nrmse_rf = (np.sqrt(mse_rf) / (np.max(y_true) - np.min(y_true))) * 100

print(f"Random Forest NRMSE: {nrmse_rf:.2f}%")
print(f"Random Forest R2 (Fz): {r2_score(y_true[:, 2], rf_preds[:, 2]):.4f}")
# Out:
# Random Forest NRMSE: 3.30%
# Random Forest R2 (Fz): 0.9484

# %%
import matplotlib.pyplot as plt

# 1. Use the correct variable from your previous run
# We must use 'rf_preds' which contains the rescaled Newton values
plt.figure(figsize=(12, 6))
plt.plot(y_actual[:200, 2], color='black', label='Target (Real Fz)')
plt.plot(rf_preds[:200, 2], color='red', linestyle=':', label='Random Forest Prediction')

# 2. Add professional formatting
plt.title('Random Forest Baseline: Fz Prediction Accuracy')
plt.xlabel('Time Steps')
plt.ylabel('Force (N)')
plt.legend()
plt.grid(True, alpha=0.3)

# 3. Save for your GitHub and Report
plt.savefig('rf_result.png')
plt.show()
